# %% [markdown]
# <a href="https://colab.research.google.com/github/monicasjsu/deep_learning/blob/master/6_volumetric_ct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import numpy as np
import torch
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dir_path = "drive/My Drive/data/p1ch4/volumetric-dicom/2-LUNG 3.0 B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# 99/99 files (100.0%)
#   Found 1 correct series.
# 99/99  (100.0%)
# (99, 512, 512)

# %% [markdown]
# Making room for the channel dimension by using
# unsqueeze

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.transpose(vol, 0, 2)
vol = torch.unsqueeze(vol, 0)
vol.shape
# Out:
# torch.Size([1, 512, 512, 99])

# %%
plt.imshow(vol_arr[80])
