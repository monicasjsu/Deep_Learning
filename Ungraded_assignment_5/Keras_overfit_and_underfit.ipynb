# %% [markdown]
# <a href="https://colab.research.google.com/github/monicasjsu/deep_learning/blob/master/Keras_overfit_and_underfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)

# !pip install git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
# Out:
# 2.2.0-rc3
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-rp2fot_t
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-rp2fot_t
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0d92131b8cc983025d3b423255b1afb09683fbed9-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0d92131b8cc983025d3b423255b1afb09683fbed9-) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0d92131b8cc983025d3b423255b1afb09683fbed9-) (1.12.0)
# Collecting pathlib2
#   Downloading https://files.pythonhosted.org/packages/e9/45/9c82d3666af4ef9f221cbb954e1d77ddbb513faf552aea6df5f37f1a4859/pathlib2-2.3.5-py2.py3-none-any.whl
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0d92131b8cc983025d3b423255b1afb09683fbed9-) (3.13)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0d92131b8cc983025d3b423255b1afb09683fbed9_-cp36-none-any.whl size=98708 sha256=0303c4d51e13883e57b38c3d8745b85dbf95bd3b5fbca45823016d9582085a6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cb3r7rox/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# Installing collected packages: pathlib2, tensorflow-docs
# Successfully installed pathlib2-2.3.5 tensorflow-docs-0.0.0d92131b8cc983025d3b423255b1afb09683fbed9-

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816409600/2816407858 [==============================] - 122s 0us/step

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset shapes: ((28,), ()), types: (tf.float32, tf.float32)>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4828,  binary_crossentropy:0.8176,  loss:0.8176,  val_accuracy:0.4530,  val_binary_crossentropy:0.8079,  val_loss:0.8079,
# ....................................................................................................
# Epoch: 100, accuracy:0.5900,  binary_crossentropy:0.6303,  loss:0.6303,  val_accuracy:0.5820,  val_binary_crossentropy:0.6231,  val_loss:0.6231,
# ....................................................................................................
# Epoch: 200, accuracy:0.6062,  binary_crossentropy:0.6228,  loss:0.6228,  val_accuracy:0.5990,  val_binary_crossentropy:0.6156,  val_loss:0.6156,
# ....................................................................................................
# Epoch: 300, accuracy:0.6147,  binary_crossentropy:0.6183,  loss:0.6183,  val_accuracy:0.6150,  val_binary_crossentropy:0.6088,  val_loss:0.6088,
# ....................................................................................................
# Epoch: 400, accuracy:0.6309,  binary_crossentropy:0.6130,  loss:0.6130,  val_accuracy:0.6210,  val_binary_crossentropy:0.6043,  val_loss:0.6043,
# ....................................................................................................
# Epoch: 500, accuracy:0.6348,  binary_crossentropy:0.6080,  loss:0.6080,  val_accuracy:0.6490,  val_binary_crossentropy:0.5982,  val_loss:0.5982,
# ....................................................................................................
# Epoch: 600, accuracy:0.6448,  binary_crossentropy:0.6033,  loss:0.6033,  val_accuracy:0.6390,  val_binary_crossentropy:0.5951,  val_loss:0.5951,
# ....................................................................................................
# Epoch: 700, accuracy:0.6516,  binary_crossentropy:0.5978,  loss:0.5978,  val_accuracy:0.6440,  val_binary_crossentropy:0.5915,  val_loss:0.5915,
# ....................................................................................................
# Epoch: 800, accuracy:0.6546,  binary_crossentropy:0.5931,  loss:0.5931,  val_accuracy:0.6520,  val_binary_crossentropy:0.5891,  val_loss:0.5891,
# ....................................................................................................
# Epoch: 900, accuracy:0.6593,  binary_crossentropy:0.5900,  loss:0.5900,  val_accuracy:0.6490,  val_binary_crossentropy:0.5866,  val_loss:0.5866,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6604,  binary_crossentropy:0.5876,  loss:0.5876,  val_accuracy:0.6650,  val_binary_crossentropy:0.5842,  val_loss:0.5842,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6640,  binary_crossentropy:0.5856,  loss:0.5856,  val_accuracy:0.6440,  val_binary_crossentropy:0.5863,  val_loss:0.5863,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6650,  binary_crossentropy:0.5843,  loss:0.5843,  val_accuracy:0.6680,  val_binary_crossentropy:0.5833,  val_loss:0.5833,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6709,  binary_crossentropy:0.5831,  loss:0.5831,  val_accuracy:0.6420,  val_binary_crossentropy:0.5879,  val_loss:0.5879,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6693,  binary_crossentropy:0.5815,  loss:0.5815,  val_accuracy:0.6560,  val_binary_crossentropy:0.5837,  val_loss:0.5837,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6688,  binary_crossentropy:0.5804,  loss:0.5804,  val_accuracy:0.6620,  val_binary_crossentropy:0.5833,  val_loss:0.5833,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6667,  binary_crossentropy:0.5798,  loss:0.5798,  val_accuracy:0.6660,  val_binary_crossentropy:0.5830,  val_loss:0.5830,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6704,  binary_crossentropy:0.5789,  loss:0.5789,  val_accuracy:0.6690,  val_binary_crossentropy:0.5826,  val_loss:0.5826,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6725,  binary_crossentropy:0.5781,  loss:0.5781,  val_accuracy:0.6570,  val_binary_crossentropy:0.5832,  val_loss:0.5832,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6723,  binary_crossentropy:0.5775,  loss:0.5775,  val_accuracy:0.6600,  val_binary_crossentropy:0.5832,  val_loss:0.5832,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6758,  binary_crossentropy:0.5769,  loss:0.5769,  val_accuracy:0.6530,  val_binary_crossentropy:0.5832,  val_loss:0.5832,
# ....................................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4789,  binary_crossentropy:0.8201,  loss:0.8201,  val_accuracy:0.4760,  val_binary_crossentropy:0.7575,  val_loss:0.7575,
# ....................................................................................................
# Epoch: 100, accuracy:0.6218,  binary_crossentropy:0.6131,  loss:0.6131,  val_accuracy:0.6140,  val_binary_crossentropy:0.6121,  val_loss:0.6121,
# ....................................................................................................
# Epoch: 200, accuracy:0.6569,  binary_crossentropy:0.5931,  loss:0.5931,  val_accuracy:0.6610,  val_binary_crossentropy:0.5946,  val_loss:0.5946,
# ....................................................................................................
# Epoch: 300, accuracy:0.6738,  binary_crossentropy:0.5809,  loss:0.5809,  val_accuracy:0.6580,  val_binary_crossentropy:0.5843,  val_loss:0.5843,
# ....................................................................................................
# Epoch: 400, accuracy:0.6759,  binary_crossentropy:0.5743,  loss:0.5743,  val_accuracy:0.6680,  val_binary_crossentropy:0.5821,  val_loss:0.5821,
# ....................................................................................................
# Epoch: 500, accuracy:0.6816,  binary_crossentropy:0.5684,  loss:0.5684,  val_accuracy:0.6650,  val_binary_crossentropy:0.5821,  val_loss:0.5821,
# ....................................................................................................
# Epoch: 600, accuracy:0.6814,  binary_crossentropy:0.5660,  loss:0.5660,  val_accuracy:0.6570,  val_binary_crossentropy:0.5831,  val_loss:0.5831,
# ....................................................................................................
# Epoch: 700, accuracy:0.6850,  binary_crossentropy:0.5625,  loss:0.5625,  val_accuracy:0.6600,  val_binary_crossentropy:0.5824,  val_loss:0.5824,
# ..................................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4913,  binary_crossentropy:0.6905,  loss:0.6905,  val_accuracy:0.4920,  val_binary_crossentropy:0.6739,  val_loss:0.6739,
# ....................................................................................................
# Epoch: 100, accuracy:0.7183,  binary_crossentropy:0.5243,  loss:0.5243,  val_accuracy:0.6860,  val_binary_crossentropy:0.6064,  val_loss:0.6064,
# ....................................................................................................
# Epoch: 200, accuracy:0.7928,  binary_crossentropy:0.4221,  loss:0.4221,  val_accuracy:0.6480,  val_binary_crossentropy:0.7072,  val_loss:0.7072,
# .......................................................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5076,  binary_crossentropy:0.7659,  loss:0.7659,  val_accuracy:0.5140,  val_binary_crossentropy:0.6715,  val_loss:0.6715,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0022,  loss:0.0022,  val_accuracy:0.6510,  val_binary_crossentropy:1.9028,  val_loss:1.9028,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6520,  val_binary_crossentropy:2.6054,  val_loss:2.6054,
# ............................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97",
    width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# PosixPath('/tmp/tmp3d84grj2/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %% [markdown]
# Adding weight regularization

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5124,  binary_crossentropy:0.7898,  loss:2.3049,  val_accuracy:0.5700,  val_binary_crossentropy:0.6723,  val_loss:2.1083,
# ....................................................................................................
# Epoch: 100, accuracy:0.6613,  binary_crossentropy:0.5936,  loss:0.6181,  val_accuracy:0.6820,  val_binary_crossentropy:0.5832,  val_loss:0.6075,
# ....................................................................................................
# Epoch: 200, accuracy:0.6807,  binary_crossentropy:0.5816,  loss:0.6052,  val_accuracy:0.6650,  val_binary_crossentropy:0.5829,  val_loss:0.6062,
# ....................................................................................................
# Epoch: 300, accuracy:0.6893,  binary_crossentropy:0.5694,  loss:0.5934,  val_accuracy:0.6630,  val_binary_crossentropy:0.5842,  val_loss:0.6082,
# ....................................................................................................
# Epoch: 400, accuracy:0.6988,  binary_crossentropy:0.5579,  loss:0.5860,  val_accuracy:0.6880,  val_binary_crossentropy:0.5760,  val_loss:0.6041,
# ....................................................................................................
# Epoch: 500, accuracy:0.7041,  binary_crossentropy:0.5527,  loss:0.5814,  val_accuracy:0.6750,  val_binary_crossentropy:0.5784,  val_loss:0.6071,
# ....................................................................................................
# Epoch: 600, accuracy:0.7045,  binary_crossentropy:0.5468,  loss:0.5762,  val_accuracy:0.6810,  val_binary_crossentropy:0.5758,  val_loss:0.6053,
# ....................................................................................................
# Epoch: 700, accuracy:0.7124,  binary_crossentropy:0.5400,  loss:0.5695,  val_accuracy:0.6740,  val_binary_crossentropy:0.5794,  val_loss:0.6090,
# .....................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
result = l2_model(features)
regularization_loss=tf.add_n(l2_model.losses)

# %% [markdown]
# Dropout

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5043,  binary_crossentropy:0.7972,  loss:0.7972,  val_accuracy:0.5400,  val_binary_crossentropy:0.6709,  val_loss:0.6709,
# ....................................................................................................
# Epoch: 100, accuracy:0.6556,  binary_crossentropy:0.5939,  loss:0.5939,  val_accuracy:0.6780,  val_binary_crossentropy:0.5750,  val_loss:0.5750,
# ....................................................................................................
# Epoch: 200, accuracy:0.6945,  binary_crossentropy:0.5564,  loss:0.5564,  val_accuracy:0.6820,  val_binary_crossentropy:0.5817,  val_loss:0.5817,
# ....................................................................................................
# Epoch: 300, accuracy:0.7206,  binary_crossentropy:0.5116,  loss:0.5116,  val_accuracy:0.6710,  val_binary_crossentropy:0.6054,  val_loss:0.6054,
# ..................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# Combined L2 + Dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5049,  binary_crossentropy:0.7872,  loss:0.9456,  val_accuracy:0.4720,  val_binary_crossentropy:0.6924,  val_loss:0.8500,
# ....................................................................................................
# Epoch: 100, accuracy:0.6448,  binary_crossentropy:0.6074,  loss:0.6347,  val_accuracy:0.6480,  val_binary_crossentropy:0.5958,  val_loss:0.6228,
# ....................................................................................................
# Epoch: 200, accuracy:0.6611,  binary_crossentropy:0.5932,  loss:0.6183,  val_accuracy:0.6830,  val_binary_crossentropy:0.5687,  val_loss:0.5938,
# ....................................................................................................
# Epoch: 300, accuracy:0.6689,  binary_crossentropy:0.5853,  loss:0.6130,  val_accuracy:0.6770,  val_binary_crossentropy:0.5621,  val_loss:0.5898,
# ....................................................................................................
# Epoch: 400, accuracy:0.6726,  binary_crossentropy:0.5852,  loss:0.6146,  val_accuracy:0.6820,  val_binary_crossentropy:0.5587,  val_loss:0.5881,
# ....................................................................................................
# Epoch: 500, accuracy:0.6807,  binary_crossentropy:0.5703,  loss:0.6020,  val_accuracy:0.6950,  val_binary_crossentropy:0.5533,  val_loss:0.5850,
# ....................................................................................................
# Epoch: 600, accuracy:0.6819,  binary_crossentropy:0.5723,  loss:0.6061,  val_accuracy:0.6840,  val_binary_crossentropy:0.5506,  val_loss:0.5844,
# ....................................................................................................
# Epoch: 700, accuracy:0.6832,  binary_crossentropy:0.5646,  loss:0.5994,  val_accuracy:0.6940,  val_binary_crossentropy:0.5403,  val_loss:0.5751,
# ....................................................................................................
# Epoch: 800, accuracy:0.6902,  binary_crossentropy:0.5595,  loss:0.5957,  val_accuracy:0.7110,  val_binary_crossentropy:0.5430,  val_loss:0.5791,
# ....................................................................................................
# Epoch: 900, accuracy:0.6893,  binary_crossentropy:0.5540,  loss:0.5913,  val_accuracy:0.7120,  val_binary_crossentropy:0.5422,  val_loss:0.5795,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6951,  binary_crossentropy:0.5532,  loss:0.5916,  val_accuracy:0.6780,  val_binary_crossentropy:0.5500,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6970,  binary_crossentropy:0.5482,  loss:0.5878,  val_accuracy:0.7050,  val_binary_crossentropy:0.5427,  val_loss:0.5824,
# ....................................................................................................
# Epoch: 1200, accuracy:0.7009,  binary_crossentropy:0.5512,  loss:0.5919,  val_accuracy:0.6970,  val_binary_crossentropy:0.5533,  val_loss:0.5940,
# ...................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
